# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustinO28/Projet_Data_GR3/blob/main/Cours_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "alice"
height = 1.85 #data type is Num
is_student = True #Bolean

# %%
height
print (height)
# Out:
# 1.85

# %%
# Il existe depuis la maj un F PRINT
print (f"(a) fait (height) en m, et est une etudiante (1s_student)")
# Out:
# (a) fait (height) en m, et est une etudiante (1s_student)

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
